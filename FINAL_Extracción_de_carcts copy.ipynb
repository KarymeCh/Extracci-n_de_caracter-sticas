# %%
#Importamos las librerías pandas, numpy y matplotlib respextivamente
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('NuevaOrleans_SinValoresAtípicos copy.csv')

# %%
#verificcamos informacion del dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7522 entries, 0 to 7521
# Data columns (total 45 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   host_response_rate           7522 non-null   float64
#  1   latitude                     7522 non-null   float64
#  2   longitude                    7522 non-null   float64
#  3   neighbourhood_cleansed       7522 non-null   object
#  4   property_type                7522 non-null   object
#  5   room_type                    7522 non-null   object
#  6   host_since                   7522 non-null   object
#  7   host_location                7522 non-null   object
#  8   host_response_time           7522 non-null   object
#  9   host_is_superhost            7522 non-null   object
#  10  host_has_profile_pic         7522 non-null   object
#  11  host_identity_verified       7522 non-null   object
#  12  bathrooms_text               7522 non-null   object
# ...

# %%
#imprimo los primeros 5 registros del dataframe
df.head()
# Out:
#    host_response_rate  latitude  longitude neighbourhood_cleansed  \
# 0               100.0  29.96100  -90.11950               Leonidas
# 1               100.0  29.96153  -90.04364                Bywater
# 2               100.0  29.97803  -90.07450           Seventh Ward
# 3               100.0  29.96448  -90.03667             St. Claude
# 4               100.0  29.96811  -90.05905                Marigny
#
#           property_type        room_type  host_since    host_location  \
# 0    Entire rental unit  Entire home/apt  2010-01-23  New Orleans, LA
# 1    Entire rental unit  Entire home/apt  2011-01-29  New Orleans, LA
# 2    Entire rental unit  Entire home/apt  2011-03-07  New Orleans, LA
# 3    Entire guest suite  Entire home/apt  2011-03-07  New Orleans, LA
# 4  Private room in home     Private room  2011-03-12  New Orleans, LA
#
#   host_response_time host_is_superhost  ... number_of_reviews  \
# 0     within an hour                 f  ...              18.0
# ...

# %% [markdown]
# **ANÁLISIS UNIVARIADO**
#
# Realicé una tabla de frecuencia para 10 variables categóricas que conformaban mi dataset, de esta manera pude graficar los resultados.
# En esta sección verifiqué que al realizar el índice de cada variable se conservaran rangos significativos y que no tuvieran muestras demasiadas pequeñas, para así visualizar información que brindara un buen análisis.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq = df['host_response_time'].value_counts(). reset_index()
tabla_freq
# Out:
#    host_response_time  count
# 0      within an hour   6639
# 1  within a few hours    541
# 2        within a day    296
# 3  a few days or more     46

# %%
#ajusto el indice de mi dataframe
filtro_index = tabla_freq.set_index('host_response_time')
filtro_index
# Out:
#                     count
# host_response_time
# within an hour       6639
# within a few hours    541
# within a day          296
# a few days or more     46

# %%
filtro_index['count'].plot(
    kind='pie',
    figsize=(10, 5),
    shadow=True,
    autopct='%0.1f %%',
    colors=plt.cm.Set3.colors  # 🎨 paleta pastel
)
plt.title("Tiempo de respuesta de los anfitriones", fontsize=16, fontweight="bold")
plt.show()

# %% [markdown]
# Se observa que el 88.3% de los anfitriones mantinen su tiempo de respuesta en una hora o menos. Esto tiene sentido ya ques forma parte de la percepción que generan a sus clientes, y mientras más rápido contesten, mejor será el servicio otorgado.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq2 = df['property_type'].value_counts(). reset_index()
tabla_freq2
# Out:
#                         property_type  count
# 0                         Entire home   2759
# 1                  Entire rental unit   1929
# 2                        Entire condo    983
# 3                Private room in home    319
# 4                       Room in hotel    315
# 5                    Entire townhouse    181
# 6                  Entire guest suite    174
# 7                   Entire guesthouse    150
# 8   Private room in bed and breakfast    110
# 9           Entire serviced apartment    100
# 10             Room in boutique hotel     77
# 11        Private room in rental unit     72
# 12                        Entire loft     44
# 13                     Entire cottage     43
# 14        Private room in guest suite     36
# 15                       Entire villa     36
# 16             Private room in resort     34
# 17                    Entire bungalow     16
# 18         Private room in guesthouse     16
# 19               Entire vacation home     13
# ...

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro2 = tabla_freq2[tabla_freq2['count']>=100]
filtro2
# Out:
#                        property_type  count
# 0                        Entire home   2759
# 1                 Entire rental unit   1929
# 2                       Entire condo    983
# 3               Private room in home    319
# 4                      Room in hotel    315
# 5                   Entire townhouse    181
# 6                 Entire guest suite    174
# 7                  Entire guesthouse    150
# 8  Private room in bed and breakfast    110
# 9          Entire serviced apartment    100

# %%
#ajusto el indice de mi dataframe
filtro_index2 = filtro2.set_index('property_type')
filtro_index2
# Out:
#                                    count
# property_type
# Entire home                         2759
# Entire rental unit                  1929
# Entire condo                         983
# Private room in home                 319
# Room in hotel                        315
# Entire townhouse                     181
# Entire guest suite                   174
# Entire guesthouse                    150
# Private room in bed and breakfast    110
# Entire serviced apartment            100

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index2.plot(kind='bar', width = 0.8, figsize = (10, 4), color=plt.cm.Set2.colors) 
plt.title('TIPOS DE PROPIEDADES', fontsize=16, fontweight='bold') 
plt.xlabel('Propiedades') 
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# En Nueva Orleans, el tipo de propiedad rentada que predomina es "Entire home", luego "Entire rental unit" y "entire condo", lo que nos sugiere que en su mayoría se buscan espacios grandes, tal ve esté aunado a que viajan grupos grandes de personas.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq3 = df['neighbourhood_cleansed'].value_counts(). reset_index()
tabla_freq3
# Out:
#        neighbourhood_cleansed  count
# 0   Central Business District   1333
# 1                Central City    681
# 2                    Mid-City    436
# 3                     Marigny    426
# 4                Seventh Ward    422
# 5             Treme - Lafitte    392
# 6       Lower Garden District    341
# 7                  St. Claude    298
# 8                     Bywater    233
# 9              French Quarter    221
# 10           Tulane - Gravier    184
# 11                   St. Roch    179
# 12             Bayou St. John    129
# 13                Fairgrounds    123
# 14                   Leonidas    118
# 15              Irish Channel    118
# 16                      Milan    116
# 17                     Uptown    111
# 18             West Riverside    111
# 19                  Broadmoor    108
# 20                    Audubon     99
# 21             East Riverside     97
# 22  Marlyville - Fontainbleau     74
# 23           Gentilly Terrace     72
# ...

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro3 = tabla_freq3[tabla_freq3['count']>=179]
filtro3
# Out:
#        neighbourhood_cleansed  count
# 0   Central Business District   1333
# 1                Central City    681
# 2                    Mid-City    436
# 3                     Marigny    426
# 4                Seventh Ward    422
# 5             Treme - Lafitte    392
# 6       Lower Garden District    341
# 7                  St. Claude    298
# 8                     Bywater    233
# 9              French Quarter    221
# 10           Tulane - Gravier    184
# 11                   St. Roch    179

# %%
#ajusto el indice de mi dataframe
filtro_index3 = filtro3.set_index('neighbourhood_cleansed')
filtro_index3
# Out:
#                            count
# neighbourhood_cleansed
# Central Business District   1333
# Central City                 681
# Mid-City                     436
# Marigny                      426
# Seventh Ward                 422
# Treme - Lafitte              392
# Lower Garden District        341
# St. Claude                   298
# Bywater                      233
# French Quarter               221
# Tulane - Gravier             184
# St. Roch                     179

# %%
filtro_index3.plot(
    kind='barh',                   # barras horizontales
    width=0.8,
    figsize=(10, 6),               # un poco más alto para que se vea cómodo
    color=plt.cm.Set3.colors[:len(filtro_index3)]  # un color distinto por barra
)

plt.title('NEIGHBOURHOODS CLEANSED', fontsize=16, fontweight='bold')
plt.xlabel('Frecuencia')
plt.ylabel('Neighbourhoods')
plt.gca().invert_yaxis()  # opcional: poner la barra más alta arriba
plt.show()

# %% [markdown]
# Hace referencia a como los "guests" limpian antes de dejar el lugar. Hay una mayor concentración de personas que limpian en Central Business District y en Central City, que sugiere que las personas que se alojan ahí mantienen mayor orden, esto puede ser una característica importante de la zona, pues se asocian espacios de negocio y trabajo.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq4 = df['room_type'].value_counts(). reset_index()
tabla_freq4
# Out:
#          room_type  count
# 0  Entire home/apt   6474
# 1     Private room    924
# 2       Hotel room    117
# 3      Shared room      7

# %%
#ajusto el indice de mi dataframe
filtro_index4 = tabla_freq4.set_index('room_type')
filtro_index4
# Out:
#                  count
# room_type
# Entire home/apt   6474
# Private room       924
# Hotel room         117
# Shared room          7

# %%
# Elegimos un color pastel
color_linea = plt.cm.Set3(6)  # toma el primer color de la paleta Set3

# Gráfico lineal
filtro_index4.plot(
    kind='line',
    figsize=(10, 5),
    marker='o',           # marca los puntos de cada valor
    linewidth=2,
    color=color_linea
)

plt.title('Frecuencia por tipo de habitación', fontsize=16, fontweight='bold')
plt.xlabel('Tipo de habitación')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)  # cuadrícula suave
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# En este gráfico se observa que hay una fuerte preferencia por las habitaciones enteras, más que por cualquier otro tipo.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq5 = df['host_since'].value_counts(). reset_index()

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro5 = tabla_freq5[tabla_freq5['count']>=60]
filtro5
# Out:
#     host_since  count
# 0   2022-01-31    178
# 1   2023-02-20     94
# 2   2023-11-09     87
# 3   2024-02-10     82
# 4   2016-03-28     79
# 5   2017-01-23     74
# 6   2024-03-27     74
# 7   2016-03-24     66
# 8   2020-06-08     66
# 9   2024-06-26     66
# 10  2016-12-05     65
# 11  2019-07-17     60

# %%
#ajusto el indice de mi dataframe
filtro_index5 = filtro5.set_index('host_since')
filtro_index5
# Out:
#             count
# host_since
# 2022-01-31    178
# 2023-02-20     94
# 2023-11-09     87
# 2024-02-10     82
# 2016-03-28     79
# 2017-01-23     74
# 2024-03-27     74
# 2016-03-24     66
# 2020-06-08     66
# 2024-06-26     66
# 2016-12-05     65
# 2019-07-17     60

# %%
# Elegimos un color pastel
color_linea = plt.cm.Set3(2)  # toma el primer color de la paleta Set3

# Gráfico lineal
filtro_index5.plot(
    kind='line',
    figsize=(10, 5),
    marker='o',           # marca los puntos de cada valor
    linewidth=2,
    color=color_linea
)

plt.title('Frecuencia por fechas de unión como host', fontsize=16, fontweight='bold')
plt.xlabel('Host since')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)  # cuadrícula suave
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# El año más relevante para nuevas uniones de Airbnb es en el 2022, siendo este un año importante para el crecimiento de la empresa dentro de Nueva Orleans.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq6 = df['host_is_superhost'].value_counts(). reset_index()
tabla_freq6
# Out:
#   host_is_superhost  count
# 0                 f   4297
# 1                 t   3225

# %%
#ajusto el indice de mi dataframe
filtro_index6 = tabla_freq6.set_index('host_is_superhost')
filtro_index6
# Out:
#                    count
# host_is_superhost
# f                   4297
# t                   3225

# %%
filtro_index6.plot(
    kind='bar',
    width=0.6,
    figsize=(10, 4),
    color=plt.cm.Set3_r.colors,  # 🎨 paleta pastel
    edgecolor='black',  # borde de las barras
    alpha=0.8  # transparencia
)

plt.title('¿Es Superhost?', fontsize=14, fontweight='bold')
plt.xlabel('Distribución de Superhosts', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.xticks(rotation=0)  # etiquetas horizontales
plt.show()

# %% [markdown]
# La mayoría de personas coincide que en la muestra de más de 7000 encuestas, dentro de Nueva Orleans,más de la mitad no es superhost, esto es un punto a evaluar si la marca desea conseguir la ditinción dentro del estado.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq7 = df['host_has_profile_pic'].value_counts(). reset_index()
tabla_freq7
# Out:
#   host_has_profile_pic  count
# 0                    t   7331
# 1                    f    191

# %%
#ajusto el indice de mi dataframe
filtro_index7 = tabla_freq7.set_index('host_has_profile_pic')
filtro_index7
# Out:
#                       count
# host_has_profile_pic
# t                      7331
# f                       191

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index7.plot(kind='barh', width = 0.8, figsize = (10, 4), color = plt.cm.Pastel1.colors)
plt.title('¿Tiene foto de perfil?')
plt.xlabel('Disponibilidad de Foto de Perfil en Hosts')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# La gran mayoría de hosts cuentan con foto de perfil, lo que genera confianza para quienes adquieren este servicio.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq8 = df['host_identity_verified'].value_counts(). reset_index()
tabla_freq8
# Out:
#   host_identity_verified  count
# 0                      t   6351
# 1                      f   1171

# %%
#ajusto el indice de mi dataframe
filtro_index8 = tabla_freq8.set_index('host_identity_verified')
filtro_index8
# Out:
#                         count
# host_identity_verified
# t                        6351
# f                        1171

# %%
# Gráfico de anillo
plt.figure(figsize=(6,6))
plt.pie(
    filtro_index8['count'],
    labels=filtro_index8.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Set3.colors,   # paleta pastel
    wedgeprops=dict(width=0.4)   # 👈 esto crea el "agujero"
)

plt.title('Host Identity Verified', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# Considero que este es uno de los insights más importantes, pues se esperaría tener un número más alto de hosts verificado. Aunque la gran mayoría si cuenta con verificación, al ser este un servicio de hospedaje sería conveniente verificar a todos los hosts dentro de la plataforma.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq9 = df['bathrooms_text'].value_counts(). reset_index()

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro9 = tabla_freq9[tabla_freq9['count']>=51]
filtro9
# Out:
#     bathrooms_text  count
# 0           1 bath   3278
# 1          2 baths   1921
# 2   1 private bath    499
# 3          3 baths    394
# 4        2.5 baths    333
# 5        1.5 baths    287
# 6          4 baths    189
# 7    1 shared bath    166
# 8        3.5 baths    121
# 9          5 baths     78
# 10       4.5 baths     51

# %%
#ajusto el indice de mi dataframe
filtro_index9 = filtro9.set_index('bathrooms_text')
filtro_index9
# Out:
#                 count
# bathrooms_text
# 1 bath           3278
# 2 baths          1921
# 1 private bath    499
# 3 baths           394
# 2.5 baths         333
# 1.5 baths         287
# 4 baths           189
# 1 shared bath     166
# 3.5 baths         121
# 5 baths            78
# 4.5 baths          51

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index9.plot(kind='bar', width = 0.8, figsize = (10, 4), color = plt.cm.Pastel2.colors)
plt.title('Distribución de Tipos de Baños')
plt.xlabel('Descripción del baño')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Casi la mitad de lugares registrados en la plataformas cuentan con un baño, lo que indica que los lugares son de tamaño mediano en su mayoría, y en segundo lugar tenemos dos baños, para lugares más espaciosos.

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq10 = df['host_location'].value_counts(). reset_index()

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro10 = tabla_freq10[tabla_freq10['count']>=40]
filtro10
# Out:
#               host_location  count
# 0           New Orleans, LA   6112
# 1              Metairie, LA     73
# 2   New York, United States     65
# 3             United States     63
# 4           Los Angeles, CA     56
# 5              New York, NY     55
# 6  Louisiana, United States     40
# 7                Austin, TX     40
# 8           Princeville, HI     40

# %%
#ajusto el indice de mi dataframe
filtro_index10 = filtro10.set_index('host_location')
filtro_index10
# Out:
#                           count
# host_location
# New Orleans, LA            6112
# Metairie, LA                 73
# New York, United States      65
# United States                63
# Los Angeles, CA              56
# New York, NY                 55
# Louisiana, United States     40
# Austin, TX                   40
# Princeville, HI              40

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index10.plot(kind='barh', width = 0.8, figsize = (8, 5), color = plt.cm.Set3_r.colors)
plt.title('Ubicación del anfitrión')
plt.xlabel('Distribución de anfitriones por ubicación')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Se observa que la gran mayoría de hosts residen en el mismo estado, la importancia de este dato puede llegar a variar, a excepción de que se desea contactar con el propietario en situación de emergencia.

# %% [markdown]
# **#CATEGORIZAR VARIABLES**
#
# DETERMINACIÓN DE CLASES POR DATOS GRUPALES

# %%
pd.options.display.max_rows = None

# %%
valores_nulos=df.isnull().sum().sum()
valores_nulos
# Out:
# np.int64(0)

# %% [markdown]
# 1ERA CATEGORIZACIÓN

# %%
#calcula el número total
df['host_response_rate'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: host_response_rate
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['host_response_rate'].max()
Min = df['host_response_rate'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(0.0), np.float64(100.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(100.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(7.206075362985583)

# %%
intervalos = np.linspace(-1,101,15)
intervalos

#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
# Out:
# array([ -1.        ,   6.28571429,  13.57142857,  20.85714286,
#         28.14285714,  35.42857143,  42.71428571,  50.        ,
#         57.28571429,  64.57142857,  71.85714286,  79.14285714,
#         86.42857143,  93.71428571, 101.        ])

# %%
#creamos las categorías

categorias = ['0-7.2%', '7.2-14.4%', '14.4-21.6%', '21.6-28.8%', '28.8-36%', '36-43.2%', '43.2-50.4%', '50.4-57.6%', '57.6-64.8%', '64.8-72%', '72-79.2%', '79.2-86.4%', '86.4-93.6%', '93.6-100%']

# %%
#Finalmente creamos las categorías en la columna numérica

df['host_response_rate'] = pd.cut(x=df['host_response_rate'], bins=intervalos, labels=categorias)
df['host_response_rate']
# Out:
# 0        93.6-100%
# 1        93.6-100%
# 2        93.6-100%
# 3        93.6-100%
# 4        93.6-100%
# 5        93.6-100%
# 6        93.6-100%
# 7        93.6-100%
# 8        93.6-100%
# 9        93.6-100%
# 10       93.6-100%
# 11       93.6-100%
# 12      79.2-86.4%
# 13       93.6-100%
# 14       93.6-100%
# 15       93.6-100%
# 16       93.6-100%
# 17       93.6-100%
# 18       93.6-100%
# 19       93.6-100%
# 20       93.6-100%
# 21       93.6-100%
# 22       93.6-100%
# 23       93.6-100%
# 24       93.6-100%
# 25       93.6-100%
# 26       93.6-100%
# 27       93.6-100%
# 28       93.6-100%
# 29       7.2-14.4%
# 30       93.6-100%
# 31       93.6-100%
# 32       93.6-100%
# 33       93.6-100%
# 34       93.6-100%
# 35       93.6-100%
# 36       93.6-100%
# 37       93.6-100%
# 38       93.6-100%
# 39       93.6-100%
# 40       93.6-100%
# 41       93.6-100%
# 42       93.6-100%
# 43       93.6-100%
# 44       93.6-100%
# 45       93.6-100%
# 46       93.6-100%
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq11 = df['host_response_rate'].value_counts(). reset_index()
tabla_freq11
# Out:
#    host_response_rate  count
# 0           93.6-100%   7173
# 1          86.4-93.6%    158
# 2          79.2-86.4%     69
# 3            64.8-72%     42
# 4              0-7.2%     27
# 5          43.2-50.4%     25
# 6            72-79.2%     17
# 7          57.6-64.8%      5
# 8           7.2-14.4%      2
# 9            28.8-36%      2
# 10         50.4-57.6%      2
# 11         14.4-21.6%      0
# 12         21.6-28.8%      0
# 13           36-43.2%      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro11 = tabla_freq11[tabla_freq11['count']>=17]
filtro11
# Out:
#   host_response_rate  count
# 0          93.6-100%   7173
# 1         86.4-93.6%    158
# 2         79.2-86.4%     69
# 3           64.8-72%     42
# 4             0-7.2%     27
# 5         43.2-50.4%     25
# 6           72-79.2%     17

# %%
#ajusto el indice de mi dataframe
filtro_index11 = filtro11.set_index('host_response_rate')
filtro_index11
# Out:
#                     count
# host_response_rate
# 93.6-100%            7173
# 86.4-93.6%            158
# 79.2-86.4%             69
# 64.8-72%               42
# 0-7.2%                 27
# 43.2-50.4%             25
# 72-79.2%               17

# %%
# Elegimos un color pastel
color_linea = plt.cm.Set3(6)  # toma el primer color de la paleta Set3

# Gráfico lineal
filtro_index11.plot(
    kind='line',
    figsize=(10, 5),
    marker='o',           # marca los puntos de cada valor
    linewidth=2,
    color=color_linea
)

plt.title('Distribución del Porcentaje de Respuesta de los Anfitriones', fontsize=16, fontweight='bold')
plt.xlabel('Porcentaje de Respuesta')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)  # cuadrícula suave
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# En su mayoría, los hosts mantienen buena comunicación con las personas que adquieren su servicio. Esto es muy bueno, pues es señal de un buen servicio, tanto de los hosts como de la plataforma en sí.

# %% [markdown]
# 2NDA CATEGORIZACIÓN

# %%
#calcula el número total
df['host_total_listings_count'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: host_total_listings_count
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['host_total_listings_count'].max()
Min = df['host_total_listings_count'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(1.0), np.float64(62.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(61.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(4.395705971421206)

# %%
intervalos = np.linspace(0,63,15)
intervalos
# Out:
# array([ 0. ,  4.5,  9. , 13.5, 18. , 22.5, 27. , 31.5, 36. , 40.5, 45. ,
#        49.5, 54. , 58.5, 63. ])

# %%
categorias = ['1-5.39', '5.39-8.78', '8.78-13.17', '13.17-17.56', '17.56-21.95', '21.95-26.34', '26.34-30.73', '30.73-35.12', '35.12-39.51', '39.51-43.9', '43.9-48.29', '48.29-52.68', '52.68-57.07', '57.07-62']

# %%
#Finalmente creamos las categorías en la columna numérica

df['host_total_listings_count'] = pd.cut(x=df['host_total_listings_count'], bins=intervalos, labels=categorias)
df['host_total_listings_count']
# Out:
# 0            1-5.39
# 1            1-5.39
# 2            1-5.39
# 3            1-5.39
# 4            1-5.39
# 5            1-5.39
# 6            1-5.39
# 7            1-5.39
# 8            1-5.39
# 9         5.39-8.78
# 10        5.39-8.78
# 11           1-5.39
# 12        5.39-8.78
# 13           1-5.39
# 14           1-5.39
# 15           1-5.39
# 16           1-5.39
# 17           1-5.39
# 18           1-5.39
# 19        5.39-8.78
# 20           1-5.39
# 21           1-5.39
# 22        5.39-8.78
# 23        5.39-8.78
# 24      13.17-17.56
# 25        5.39-8.78
# 26           1-5.39
# 27           1-5.39
# 28        5.39-8.78
# 29           1-5.39
# 30           1-5.39
# 31           1-5.39
# 32           1-5.39
# 33           1-5.39
# 34        5.39-8.78
# 35        5.39-8.78
# 36        5.39-8.78
# 37      13.17-17.56
# 38      13.17-17.56
# 39           1-5.39
# 40           1-5.39
# 41           1-5.39
# 42           1-5.39
# 43           1-5.39
# 44      13.17-17.56
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq12 = df['host_total_listings_count'].value_counts(). reset_index()
tabla_freq12
# Out:
#    host_total_listings_count  count
# 0                     1-5.39   4666
# 1                  5.39-8.78   1074
# 2                 8.78-13.17    479
# 3                13.17-17.56    364
# 4                35.12-39.51    195
# 5                21.95-26.34    146
# 6                 43.9-48.29    128
# 7                17.56-21.95    119
# 8                52.68-57.07     96
# 9                26.34-30.73     81
# 10                39.51-43.9     73
# 11               30.73-35.12     71
# 12                  57.07-62     30
# 13               48.29-52.68      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro12 = tabla_freq12[tabla_freq12['count']>=96]
filtro12
# Out:
#   host_total_listings_count  count
# 0                    1-5.39   4666
# 1                 5.39-8.78   1074
# 2                8.78-13.17    479
# 3               13.17-17.56    364
# 4               35.12-39.51    195
# 5               21.95-26.34    146
# 6                43.9-48.29    128
# 7               17.56-21.95    119
# 8               52.68-57.07     96

# %%
#ajusto el indice de mi dataframe
filtro_index12 = filtro12.set_index('host_total_listings_count')
filtro_index12
# Out:
#                            count
# host_total_listings_count
# 1-5.39                      4666
# 5.39-8.78                   1074
# 8.78-13.17                   479
# 13.17-17.56                  364
# 35.12-39.51                  195
# 21.95-26.34                  146
# 43.9-48.29                   128
# 17.56-21.95                  119
# 52.68-57.07                   96

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index12.plot(kind='bar', width = 0.8, figsize = (10, 4), color = plt.cm.Pastel2.colors)
plt.title('Distribución del número total de listados por host')
plt.xlabel('Número de listados por host')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Se puede observar que en gran mayoría (más de la mitad), un solo host tiene de 1-5 propiedades registradas en la plataforma.

# %% [markdown]
# 3RA CATEGORIZACIÓN

# %%
#calcula el número total
df['accommodates'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: accommodates
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['accommodates'].max()
Min = df['accommodates'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(1.0), np.float64(12.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(11.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(0.7926682899284141)

# %%
intervalos = np.linspace(0,13,15)
intervalos
# Out:
# array([ 0.        ,  0.92857143,  1.85714286,  2.78571429,  3.71428571,
#         4.64285714,  5.57142857,  6.5       ,  7.42857143,  8.35714286,
#         9.28571429, 10.21428571, 11.14285714, 12.07142857, 13.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['1-1.79', '1.79-2.58', '2.58-3.37', '3.37-4.16', '4.16-4.95', '4.95-5.74', '5.74-6.53', '6.53-7.32', '7.32-8.11', '8.11-8.9', '8.9-9.69', '9.69-10.48', '10.48-11.27', '11.27-12']

# %%
#Finalmente creamos las categorías en la columna numérica

df['accommodates'] = pd.cut(x=df['accommodates'], bins=intervalos, labels=categorias)
df['accommodates']
# Out:
# 0         2.58-3.37
# 1         2.58-3.37
# 2         2.58-3.37
# 3         3.37-4.16
# 4         2.58-3.37
# 5         4.16-4.95
# 6         2.58-3.37
# 7         2.58-3.37
# 8         4.16-4.95
# 9         4.16-4.95
# 10        4.16-4.95
# 11        3.37-4.16
# 12        4.95-5.74
# 13        2.58-3.37
# 14        4.16-4.95
# 15        2.58-3.37
# 16        5.74-6.53
# 17        5.74-6.53
# 18        6.53-7.32
# 19       9.69-10.48
# 20        4.16-4.95
# 21        2.58-3.37
# 22        5.74-6.53
# 23        5.74-6.53
# 24        5.74-6.53
# 25        2.58-3.37
# 26        2.58-3.37
# 27        4.16-4.95
# 28        3.37-4.16
# 29        2.58-3.37
# 30        4.16-4.95
# 31        2.58-3.37
# 32        5.74-6.53
# 33        4.16-4.95
# 34        5.74-6.53
# 35        5.74-6.53
# 36        4.16-4.95
# 37        4.16-4.95
# 38        4.16-4.95
# 39        2.58-3.37
# 40        5.74-6.53
# 41        2.58-3.37
# 42        3.37-4.16
# 43        2.58-3.37
# 44      10.48-11.27
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq13 = df['accommodates'].value_counts(). reset_index()
tabla_freq13
# Out:
#    accommodates  count
# 0     4.16-4.95   2376
# 1     2.58-3.37   1884
# 2     5.74-6.53   1487
# 3     7.32-8.11    504
# 4      8.9-9.69    428
# 5     3.37-4.16    250
# 6     4.95-5.74    242
# 7   10.48-11.27    158
# 8     1.79-2.58     91
# 9     6.53-7.32     77
# 10     8.11-8.9     18
# 11   9.69-10.48      7
# 12       1-1.79      0
# 13     11.27-12      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro13 = tabla_freq13[tabla_freq13['count']>=200]
filtro13
# Out:
#   accommodates  count
# 0    4.16-4.95   2376
# 1    2.58-3.37   1884
# 2    5.74-6.53   1487
# 3    7.32-8.11    504
# 4     8.9-9.69    428
# 5    3.37-4.16    250
# 6    4.95-5.74    242

# %%
#ajusto el indice de mi dataframe
filtro_index13 = filtro13.set_index('accommodates')
filtro_index13
# Out:
#               count
# accommodates
# 4.16-4.95      2376
# 2.58-3.37      1884
# 5.74-6.53      1487
# 7.32-8.11       504
# 8.9-9.69        428
# 3.37-4.16       250
# 4.95-5.74       242

# %%
# Gráfico de anillo
plt.figure(figsize=(6,6))
plt.pie(
    filtro_index13['count'],
    labels=filtro_index13.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Set3.colors,   # paleta pastel
    wedgeprops=dict(width=0.4)   # 👈 esto crea el "agujero"
)

plt.title('Accommodations by Host', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# Se registran en su maypría propiedades con amenidades de 4 tipos, en segundo lugar, propiedades con amenidades de 2 a 3 tipos, y finalmente de 5 a 6 tipos. Lo que indica que más de la mitad de hosts proporciona amenidades de distintos tipos en un rango de 4 a 6.

# %% [markdown]
# 4TA CATEGORIZACIÓN

# %%
#calcula el número total
df['bathrooms_text'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   object
# dtypes: object(1)
# memory usage: 58.9+ KB

# %%
df['bathrooms_text'] = df['bathrooms_text'].str.extract('(\d+\.?\d*)').astype(float)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# /var/folders/9j/wm9ykq0j7ql95x8sql60c0680000gn/T/ipykernel_59174/413000935.py:1: SyntaxWarning: invalid escape sequence '\d'
#   df['bathrooms_text'] = df['bathrooms_text'].str.extract('(\d+\.?\d*)').astype(float)

# %%
df['bathrooms_text'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: bathrooms_text
# Non-Null Count  Dtype
# --------------  -----
# 7515 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['bathrooms_text'].max()
Min = df['bathrooms_text'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(0.0), np.float64(44.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(44.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(3.1706731597136564)

# %%
intervalos = np.linspace(-1,101,15)
intervalos
# Out:
# array([ -1.        ,   6.28571429,  13.57142857,  20.85714286,
#         28.14285714,  35.42857143,  42.71428571,  50.        ,
#         57.28571429,  64.57142857,  71.85714286,  79.14285714,
#         86.42857143,  93.71428571, 101.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['0-3.17', '3.17-6.34', '6.34-9.51', '9.51-12.68', '12.68-15.85', '15.85-19.02', '19.02-22.19', '22.19-25.36', '25.36-28.53', '28.53-31.7', '31.7-34.87', '34.87-38.04', '38.04-41.21', '41.21-44']

# %%
#Finalmente creamos las categorías en la columna numérica

df['bathrooms_text'] = pd.cut(x=df['bathrooms_text'], bins=intervalos, labels=categorias)
df['bathrooms_text']
# Out:
# 0            0-3.17
# 1            0-3.17
# 2            0-3.17
# 3            0-3.17
# 4            0-3.17
# 5            0-3.17
# 6            0-3.17
# 7            0-3.17
# 8            0-3.17
# 9            0-3.17
# 10           0-3.17
# 11           0-3.17
# 12           0-3.17
# 13           0-3.17
# 14           0-3.17
# 15           0-3.17
# 16           0-3.17
# 17           0-3.17
# 18           0-3.17
# 19           0-3.17
# 20           0-3.17
# 21           0-3.17
# 22           0-3.17
# 23           0-3.17
# 24           0-3.17
# 25           0-3.17
# 26           0-3.17
# 27           0-3.17
# 28           0-3.17
# 29           0-3.17
# 30           0-3.17
# 31           0-3.17
# 32           0-3.17
# 33           0-3.17
# 34           0-3.17
# 35           0-3.17
# 36           0-3.17
# 37           0-3.17
# 38           0-3.17
# 39           0-3.17
# 40           0-3.17
# 41           0-3.17
# 42           0-3.17
# 43           0-3.17
# 44           0-3.17
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq14 = df['bathrooms_text'].value_counts(). reset_index()
tabla_freq14
# Out:
#    bathrooms_text  count
# 0          0-3.17   7448
# 1       3.17-6.34     62
# 2       6.34-9.51      4
# 3     19.02-22.19      1
# 4      9.51-12.68      0
# 5     12.68-15.85      0
# 6     15.85-19.02      0
# 7     22.19-25.36      0
# 8     25.36-28.53      0
# 9      28.53-31.7      0
# 10     31.7-34.87      0
# 11    34.87-38.04      0
# 12    38.04-41.21      0
# 13       41.21-44      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro14 = tabla_freq14[tabla_freq14['count']>=1]
filtro14
# Out:
#   bathrooms_text  count
# 0         0-3.17   7448
# 1      3.17-6.34     62
# 2      6.34-9.51      4
# 3    19.02-22.19      1

# %%
#ajusto el indice de mi dataframe
filtro_index14 = filtro14.set_index('bathrooms_text')
filtro_index14
# Out:
#                 count
# bathrooms_text
# 0-3.17           7448
# 3.17-6.34          62
# 6.34-9.51           4
# 19.02-22.19         1

# %%
filtro_index14.plot(
    kind='bar',
    width=0.6,
    figsize=(10, 4),
    color=plt.cm.Set3_r.colors,  # 🎨 paleta pastel
    edgecolor='black',  # borde de las barras
    alpha=0.8  # transparencia
)

plt.title('Distribución de tipos de baños en los alojamientos', fontsize=14, fontweight='bold')
plt.xlabel('Tipo de baño', fontsize=12)
plt.ylabel('Frecuencia', fontsize=12)
plt.xticks(rotation=0)  # etiquetas horizontales
plt.show()

# %% [markdown]
# Casi el total se encuentra acumulado en alojamientos con baños completos, lo cual está bastante bien ya que es una necesidad para un buen servicio.

# %% [markdown]
# 5TA CATEGORIZACIÓN

# %%
#calcula el número total
df['beds'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: beds
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['beds'].max()
Min = df['beds'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(1.0), np.float64(4.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(3.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(0.2161822608895675)

# %%
intervalos = np.linspace(0,5,15)
intervalos
# Out:
# array([0.        , 0.35714286, 0.71428571, 1.07142857, 1.42857143,
#        1.78571429, 2.14285714, 2.5       , 2.85714286, 3.21428571,
#        3.57142857, 3.92857143, 4.28571429, 4.64285714, 5.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['1-1.21', '1.21-1.44', '1.44-1.66', '1.66-1.88', '1.88-2.1', '2.1-2.32', '2.32-2.54', '2.54-2.76', '2.76-2.98', '2.98-3.2', '3.2-3.42', '3.42-3.64', '3.64-3.86', '3.86-4']

# %%
#Finalmente creamos las categorías en la columna numérica

df['beds'] = pd.cut(x=df['beds'], bins=intervalos, labels=categorias)
df['beds']
# Out:
# 0       1.44-1.66
# 1       1.44-1.66
# 2        2.1-2.32
# 3        2.1-2.32
# 4       1.44-1.66
# 5        2.1-2.32
# 6        2.1-2.32
# 7       1.44-1.66
# 8        2.1-2.32
# 9        2.1-2.32
# 10       2.1-2.32
# 11       2.1-2.32
# 12      2.76-2.98
# 13      1.44-1.66
# 14       2.1-2.32
# 15       2.1-2.32
# 16       2.1-2.32
# 17      2.76-2.98
# 18      3.42-3.64
# 19       2.1-2.32
# 20       2.1-2.32
# 21      1.44-1.66
# 22      2.76-2.98
# 23      2.76-2.98
# 24      3.42-3.64
# 25      1.44-1.66
# 26       2.1-2.32
# 27       2.1-2.32
# 28      2.76-2.98
# 29      1.44-1.66
# 30      3.42-3.64
# 31      1.44-1.66
# 32      3.42-3.64
# 33       2.1-2.32
# 34       2.1-2.32
# 35       2.1-2.32
# 36       2.1-2.32
# 37       2.1-2.32
# 38       2.1-2.32
# 39      1.44-1.66
# 40      2.76-2.98
# 41      1.44-1.66
# 42      2.76-2.98
# 43       2.1-2.32
# 44       2.1-2.32
# 45       2.1-2.32
# 46       2.1-2.32
# 47      3.42-3.64
# 48       2.1-2.32
# 49       2.1-2.32
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq15 = df['beds'].value_counts(). reset_index()
tabla_freq15
# Out:
#          beds  count
# 0    2.1-2.32   4153
# 1   1.44-1.66   1481
# 2   2.76-2.98   1182
# 3   3.42-3.64    706
# 4      1-1.21      0
# 5   1.21-1.44      0
# 6   1.66-1.88      0
# 7    1.88-2.1      0
# 8   2.32-2.54      0
# 9   2.54-2.76      0
# 10   2.98-3.2      0
# 11   3.2-3.42      0
# 12  3.64-3.86      0
# 13     3.86-4      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro15 = tabla_freq15[tabla_freq15['count']>=706]
filtro15
# Out:
#         beds  count
# 0   2.1-2.32   4153
# 1  1.44-1.66   1481
# 2  2.76-2.98   1182
# 3  3.42-3.64    706

# %%
#ajusto el indice de mi dataframe
filtro_index15 = filtro15.set_index('beds')
filtro_index15
# Out:
#            count
# beds
# 2.1-2.32    4153
# 1.44-1.66   1481
# 2.76-2.98   1182
# 3.42-3.64    706

# %%
# Gráfico de anillo
plt.figure(figsize=(6,6))
plt.pie(
    filtro_index15['count'],
    labels=filtro_index15.index,
    autopct='%1.1f%%',
    startangle=90,
    colors=plt.cm.Set3.colors,   # paleta pastel
)

plt.title('Camas dentro del alojamiento', fontsize=14, fontweight='bold')
plt.show()

# %% [markdown]
# Se observa que poco más de la mitad de lugares registrados tienen 2 camas, lo que indica la preferencia por habitaciones grandes o casas completas para hospedaje.

# %% [markdown]
# 6TA CATEGORIZACIÓN

# %%
#calcula el número total
df['price'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: price
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['price'].max()
Min = df['price'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(0.0), np.float64(395.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(395.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(28.463997683793053)

# %%
intervalos = np.linspace(-1,396,15)
intervalos
# Out:
# array([ -1.        ,  27.35714286,  55.71428571,  84.07142857,
#        112.42857143, 140.78571429, 169.14285714, 197.5       ,
#        225.85714286, 254.21428571, 282.57142857, 310.92857143,
#        339.28571429, 367.64285714, 396.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['0-28.46', '28.46-56.92', '56.92-85.38', '85.38-113.84', '113.84-142.3', '142.3-170.76', '170.76-199.22', '199.22-227.68', '227.68-256.14', '256.14-284.6', '284.6-313.06', '313.06-341.52', '341.52-369.98', '369.98-398' ]

# %%
#Finalmente creamos las categorías en la columna numérica

df['price'] = pd.cut(x=df['price'], bins=intervalos, labels=categorias)
df['price']
# Out:
# 0         56.92-85.38
# 1        142.3-170.76
# 2             0-28.46
# 3        113.84-142.3
# 4         56.92-85.38
# 5       313.06-341.52
# 6         56.92-85.38
# 7         56.92-85.38
# 8             0-28.46
# 9        85.38-113.84
# 10       142.3-170.76
# 11       85.38-113.84
# 12      170.76-199.22
# 13       113.84-142.3
# 14        56.92-85.38
# 15            0-28.46
# 16        56.92-85.38
# 17       142.3-170.76
# 18       113.84-142.3
# 19      341.52-369.98
# 20       113.84-142.3
# 21       85.38-113.84
# 22      313.06-341.52
# 23       142.3-170.76
# 24       142.3-170.76
# 25       113.84-142.3
# 26            0-28.46
# 27       113.84-142.3
# 28       85.38-113.84
# 29      227.68-256.14
# 30       113.84-142.3
# 31        28.46-56.92
# 32      227.68-256.14
# 33       113.84-142.3
# 34      227.68-256.14
# 35       113.84-142.3
# 36        56.92-85.38
# 37       113.84-142.3
# 38       113.84-142.3
# 39        56.92-85.38
# 40       113.84-142.3
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq16 = df['price'].value_counts(). reset_index()
tabla_freq16
# Out:
#             price  count
# 0    113.84-142.3   1458
# 1    85.38-113.84   1206
# 2         0-28.46   1163
# 3     56.92-85.38   1033
# 4    142.3-170.76    683
# 5   170.76-199.22    423
# 6   199.22-227.68    376
# 7   227.68-256.14    272
# 8     28.46-56.92    270
# 9    284.6-313.06    173
# 10   256.14-284.6    172
# 11  313.06-341.52    144
# 12  341.52-369.98     90
# 13     369.98-398     59

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro16 = tabla_freq16[tabla_freq16['count']>=100]
filtro16
# Out:
#             price  count
# 0    113.84-142.3   1458
# 1    85.38-113.84   1206
# 2         0-28.46   1163
# 3     56.92-85.38   1033
# 4    142.3-170.76    683
# 5   170.76-199.22    423
# 6   199.22-227.68    376
# 7   227.68-256.14    272
# 8     28.46-56.92    270
# 9    284.6-313.06    173
# 10   256.14-284.6    172
# 11  313.06-341.52    144

# %%
#ajusto el indice de mi dataframe
filtro_index16 = filtro16.set_index('price')
filtro_index16
# Out:
#                count
# price
# 113.84-142.3    1458
# 85.38-113.84    1206
# 0-28.46         1163
# 56.92-85.38     1033
# 142.3-170.76     683
# 170.76-199.22    423
# 199.22-227.68    376
# 227.68-256.14    272
# 28.46-56.92      270
# 284.6-313.06     173
# 256.14-284.6     172
# 313.06-341.52    144

# %%
# Elegimos un color pastel
color_linea = plt.cm.Set3(6)  # toma el primer color de la paleta Set3

# Gráfico lineal
filtro_index16.plot(
    kind='line',
    figsize=(10, 5),
    marker='o',           # marca los puntos de cada valor
    linewidth=2,
    color=color_linea
)

plt.title('Precio', fontsize=16, fontweight='bold')
plt.xlabel('Distribución de Precios')
plt.ylabel('Frecuencia')
plt.grid(True, linestyle='--', alpha=0.5)  # cuadrícula suave
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# Se observa una distribución de precios bastante amplia. Los alojamientos más cotizados no son los más baratos necesariamente, pues oscilan entre 113.84 a 142.3 dólares, nuevamentem esto refuerza la búsqueda de lugares amplios con mayores amenidades.

# %% [markdown]
# 7 CATEGORIZACIÓN

# %%
#calcula el número total
df['maximum_nights_avg_ntm'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: maximum_nights_avg_ntm
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['maximum_nights_avg_ntm'].max()
Min = df['maximum_nights_avg_ntm'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(1.6), np.float64(1125.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(1123.4)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(80.95305062778004)

# %%
intervalos = np.linspace(1.5,1126,15)
intervalos
# Out:
# array([   1.5       ,   81.82142857,  162.14285714,  242.46428571,
#         322.78571429,  403.10714286,  483.42857143,  563.75      ,
#         644.07142857,  724.39285714,  804.71428571,  885.03571429,
#         965.35714286, 1045.67857143, 1126.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['1.6-82.55', '82.55-163.6', '163.6-244.65', '244.65-325.7', '325.7-406.75', '406.75-487.8', '487.8-568.85', '568.85-649.9', '649.9-730.95', '730.95-812', '812-893.05', '893.05-974.1', '974.1-1055.15', '1055.15-1136']

# %%
#Finalmente creamos las categorías en la columna numérica

df['maximum_nights_avg_ntm'] = pd.cut(x=df['maximum_nights_avg_ntm'], bins=intervalos, labels=categorias)
df['maximum_nights_avg_ntm']
# Out:
# 0        325.7-406.75
# 1        1055.15-1136
# 2           1.6-82.55
# 3         82.55-163.6
# 4        1055.15-1136
# 5        1055.15-1136
# 6        325.7-406.75
# 7        1055.15-1136
# 8          730.95-812
# 9        325.7-406.75
# 10       325.7-406.75
# 11       1055.15-1136
# 12          1.6-82.55
# 13          1.6-82.55
# 14       163.6-244.65
# 15       1055.15-1136
# 16       568.85-649.9
# 17        82.55-163.6
# 18       1055.15-1136
# 19       325.7-406.75
# 20       1055.15-1136
# 21       1055.15-1136
# 22       1055.15-1136
# 23       1055.15-1136
# 24       325.7-406.75
# 25       1055.15-1136
# 26       1055.15-1136
# 27       1055.15-1136
# 28          1.6-82.55
# 29          1.6-82.55
# 30          1.6-82.55
# 31       325.7-406.75
# 32          1.6-82.55
# 33       1055.15-1136
# 34       1055.15-1136
# 35       1055.15-1136
# 36        82.55-163.6
# 37       487.8-568.85
# 38       487.8-568.85
# 39        82.55-163.6
# 40       1055.15-1136
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq17 = df['maximum_nights_avg_ntm'].value_counts(). reset_index()
tabla_freq17
# Out:
#    maximum_nights_avg_ntm  count
# 0            1055.15-1136   3094
# 1            325.7-406.75   2509
# 2               1.6-82.55   1062
# 3             82.55-163.6    305
# 4            163.6-244.65    156
# 5              730.95-812    126
# 6            244.65-325.7     71
# 7            487.8-568.85     58
# 8            568.85-649.9     50
# 9            406.75-487.8     34
# 10           649.9-730.95     20
# 11          974.1-1055.15     20
# 12             812-893.05     12
# 13           893.05-974.1      5

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro17 = tabla_freq17[tabla_freq17['count']>=20]
filtro17
# Out:
#    maximum_nights_avg_ntm  count
# 0            1055.15-1136   3094
# 1            325.7-406.75   2509
# 2               1.6-82.55   1062
# 3             82.55-163.6    305
# 4            163.6-244.65    156
# 5              730.95-812    126
# 6            244.65-325.7     71
# 7            487.8-568.85     58
# 8            568.85-649.9     50
# 9            406.75-487.8     34
# 10           649.9-730.95     20
# 11          974.1-1055.15     20

# %%
#ajusto el indice de mi dataframe
filtro_index17 = filtro17.set_index('maximum_nights_avg_ntm')
filtro_index17
# Out:
#                         count
# maximum_nights_avg_ntm
# 1055.15-1136             3094
# 325.7-406.75             2509
# 1.6-82.55                1062
# 82.55-163.6               305
# 163.6-244.65              156
# 730.95-812                126
# 244.65-325.7               71
# 487.8-568.85               58
# 568.85-649.9               50
# 406.75-487.8               34
# 649.9-730.95               20
# 974.1-1055.15              20

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index17.plot(kind='barh', width = 0.8, figsize = (10, 4), color = plt.cm.Pastel1.colors)
plt.title('Noches máximas promedio')
plt.xlabel('Frecuencia')
plt.ylabel('Distribución de noches máximas')
# Out:
# Text(0, 0.5, 'Distribución de noches máximas')

# %% [markdown]
# La mayoría de hosts registrados permiten de 1055 a 1136 noches máximo de aloajmiento, lo que equivale a rentar la propiedad por apróximadamente 3 años. Ens egundo lugar de frecuencia, se permite la renta del lugar por una año y en tercer lugar por casi tres meses.

# %% [markdown]
# 8 CATEGORIZACION

# %%
#calcula el número total
df['availability_365'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: availability_365
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   int64
# dtypes: int64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['availability_365'].max()
Min = df['availability_365'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.int64(0), np.int64(365)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.int64(365)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(26.302175074897377)

# %%
intervalos = np.linspace(-1,366,15)
intervalos
# Out:
# array([ -1.        ,  25.21428571,  51.42857143,  77.64285714,
#        103.85714286, 130.07142857, 156.28571429, 182.5       ,
#        208.71428571, 234.92857143, 261.14285714, 287.35714286,
#        313.57142857, 339.78571429, 366.        ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['0-26.30', '26.30-52.60', '52.60-78.90', '78.90-105.20', '105.20-131.50', '131.50-157.80', '157.80-184.10', '184.10-210.40', '210.40-236.70', '236.70-263', '263-289.30', '289.30-315.60', '315.60-341.90', '341.90-365']

# %%
#Finalmente creamos las categorías en la columna numérica

df['availability_365'] = pd.cut(x=df['availability_365'], bins=intervalos, labels=categorias)
df['availability_365']
# Out:
# 0       289.30-315.60
# 1          341.90-365
# 2             0-26.30
# 3          341.90-365
# 4       210.40-236.70
# 5          341.90-365
# 6          341.90-365
# 7       184.10-210.40
# 8             0-26.30
# 9       157.80-184.10
# 10      157.80-184.10
# 11      184.10-210.40
# 12         341.90-365
# 13         341.90-365
# 14         341.90-365
# 15            0-26.30
# 16      289.30-315.60
# 17         263-289.30
# 18         341.90-365
# 19         263-289.30
# 20         263-289.30
# 21         341.90-365
# 22      315.60-341.90
# 23      210.40-236.70
# 24        52.60-78.90
# 25       78.90-105.20
# 26        52.60-78.90
# 27         236.70-263
# 28      105.20-131.50
# 29       78.90-105.20
# 30      157.80-184.10
# 31      105.20-131.50
# 32      289.30-315.60
# 33      105.20-131.50
# 34         263-289.30
# 35      315.60-341.90
# 36            0-26.30
# 37       78.90-105.20
# 38       78.90-105.20
# 39      157.80-184.10
# 40         341.90-365
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq18 = df['availability_365'].value_counts(). reset_index()
tabla_freq18
# Out:
#    availability_365  count
# 0        341.90-365   1790
# 1           0-26.30   1023
# 2     315.60-341.90    736
# 3        263-289.30    640
# 4     157.80-184.10    612
# 5     289.30-315.60    507
# 6      78.90-105.20    454
# 7        236.70-263    375
# 8     184.10-210.40    297
# 9     131.50-157.80    284
# 10      52.60-78.90    232
# 11    210.40-236.70    231
# 12      26.30-52.60    172
# 13    105.20-131.50    169

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro18 = tabla_freq18[tabla_freq18['count']>=200]
filtro18
# Out:
#    availability_365  count
# 0        341.90-365   1790
# 1           0-26.30   1023
# 2     315.60-341.90    736
# 3        263-289.30    640
# 4     157.80-184.10    612
# 5     289.30-315.60    507
# 6      78.90-105.20    454
# 7        236.70-263    375
# 8     184.10-210.40    297
# 9     131.50-157.80    284
# 10      52.60-78.90    232
# 11    210.40-236.70    231

# %%
#ajusto el indice de mi dataframe
filtro_index18 = filtro18.set_index('availability_365')
filtro_index18
# Out:
#                   count
# availability_365
# 341.90-365         1790
# 0-26.30            1023
# 315.60-341.90       736
# 263-289.30          640
# 157.80-184.10       612
# 289.30-315.60       507
# 78.90-105.20        454
# 236.70-263          375
# 184.10-210.40       297
# 131.50-157.80       284
# 52.60-78.90         232
# 210.40-236.70       231

# %%
#Realizamos grafico de áreas del dataframe filtrado
filtro_index18.plot(kind='area', figsize = (10, 4), alpha = 1)
plt.title('Disponibilidad durante el año')
plt.xlabel('Frecuencia')
plt.ylabel('Disponibildiad')
# Out:
# Text(0, 0.5, 'Disponibildiad')

# %% [markdown]
# 1750 de 7522 propiedades registradas cuentan con dispoinibilad casi todo el año, sin embargo se oberva un declive bastante marcado para el resto de la muestra, lo que indica que las propiedades en Nueva Orleans son bastante cotizadas. Esto puede depender de la temporada en la que se desee hacer la reserva, o bien de la anticipación.

# %% [markdown]
# 9 CATEGORIZACION

# %%
#calcula el número total
df['number_of_reviews'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: number_of_reviews
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['number_of_reviews'].max()
Min = df['number_of_reviews'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(0.0), np.float64(222.0)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(222.0)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(15.997487305827995)

# %%
intervalos = np.linspace(-1,223,15)
intervalos
# Out:
# array([ -1.,  15.,  31.,  47.,  63.,  79.,  95., 111., 127., 143., 159.,
#        175., 191., 207., 223.])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['0-15.99', '15.99-31.98', '31.98-47.97', '47.97-63.96', '63.96-79.95', '79.95-95.94', '95.94-111.93', '111.93-127.92', '127.92-143.91', '143.91-159.9', '159.9-175.89', '175.89-191.88', '191.88-207.87', '207.87-223']

# %%
#Finalmente creamos las categorías en la columna numérica

df['number_of_reviews'] = pd.cut(x=df['number_of_reviews'], bins=intervalos, labels=categorias)
df['number_of_reviews']
# Out:
# 0         15.99-31.98
# 1         15.99-31.98
# 2         15.99-31.98
# 3         15.99-31.98
# 4         15.99-31.98
# 5             0-15.99
# 6        143.91-159.9
# 7         15.99-31.98
# 8             0-15.99
# 9       191.88-207.87
# 10        15.99-31.98
# 11        15.99-31.98
# 12       143.91-159.9
# 13        79.95-95.94
# 14            0-15.99
# 15        15.99-31.98
# 16      191.88-207.87
# 17      175.89-191.88
# 18        47.97-63.96
# 19       143.91-159.9
# 20        31.98-47.97
# 21        79.95-95.94
# 22        79.95-95.94
# 23       143.91-159.9
# 24      111.93-127.92
# 25        47.97-63.96
# 26      111.93-127.92
# 27        15.99-31.98
# 28        15.99-31.98
# 29            0-15.99
# 30        15.99-31.98
# 31        31.98-47.97
# 32        15.99-31.98
# 33        15.99-31.98
# 34       95.94-111.93
# 35      175.89-191.88
# 36       95.94-111.93
# 37        63.96-79.95
# 38        79.95-95.94
# 39       143.91-159.9
# 40       159.9-175.89
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq19 = df['number_of_reviews'].value_counts(). reset_index()
tabla_freq19
# Out:
#    number_of_reviews  count
# 0            0-15.99   3334
# 1        15.99-31.98   1256
# 2        31.98-47.97    583
# 3        47.97-63.96    404
# 4        63.96-79.95    374
# 5        79.95-95.94    327
# 6       95.94-111.93    242
# 7      111.93-127.92    231
# 8      127.92-143.91    180
# 9       143.91-159.9    166
# 10      159.9-175.89    137
# 11     175.89-191.88    126
# 12        207.87-223     84
# 13     191.88-207.87     78

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro19 = tabla_freq19[tabla_freq19['count']>=100]
filtro19
# Out:
#    number_of_reviews  count
# 0            0-15.99   3334
# 1        15.99-31.98   1256
# 2        31.98-47.97    583
# 3        47.97-63.96    404
# 4        63.96-79.95    374
# 5        79.95-95.94    327
# 6       95.94-111.93    242
# 7      111.93-127.92    231
# 8      127.92-143.91    180
# 9       143.91-159.9    166
# 10      159.9-175.89    137
# 11     175.89-191.88    126

# %%
#ajusto el indice de mi dataframe
filtro_index19 = filtro19.set_index('number_of_reviews')
filtro_index19
# Out:
#                    count
# number_of_reviews
# 0-15.99             3334
# 15.99-31.98         1256
# 31.98-47.97          583
# 47.97-63.96          404
# 63.96-79.95          374
# 79.95-95.94          327
# 95.94-111.93         242
# 111.93-127.92        231
# 127.92-143.91        180
# 143.91-159.9         166
# 159.9-175.89         137
# 175.89-191.88        126

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index19.plot(kind='barh', width = 0.8, figsize = (10, 4), color = 'blue')
plt.title('Número de reseñas')
plt.xlabel('Frecuencia')
plt.ylabel('Distribución del número de reseñas')
# Out:
# Text(0, 0.5, 'Distribución del número de reseñas')

# %% [markdown]
# En promedio, la gran mayoría de hosts han recibido 16 reseñas. Esto indica buena interacción entre clientes, y además buena rotación de nuevos huéspedes.

# %% [markdown]
# 10 CATEGORIZACIÓN

# %%
#calcula el número total
df['reviews_per_month'].info()
n=7522
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 7522 entries, 0 to 7521
# Series name: reviews_per_month
# Non-Null Count  Dtype
# --------------  -----
# 7522 non-null   float64
# dtypes: float64(1)
# memory usage: 58.9 KB

# %%
#obtenemos el límite superior e inferior de la columna objetivo

Max = df['reviews_per_month'].max()
Min = df['reviews_per_month'].min()
Límites= [Min, Max]
Límites
# Out:
# [np.float64(0.0), np.float64(4.85)]

# %%
#calculamos el rango R

R = Max - Min
R
# Out:
# np.float64(4.85)

# %%
#Calculamos el número de intervalos de clase "ni", aplicando la regla de Sturges
ni = 1 + 3.322 * np.log10(n)
ni
# Out:
# np.float64(13.877179319224956)

# %%
#calculamos el ancho del intervalo "i"
i = R / ni
i
# Out:
# np.float64(0.34949465510480077)

# %%
intervalos = np.linspace(-1,5.85,15)
intervalos
# Out:
# array([-1.        , -0.51071429, -0.02142857,  0.46785714,  0.95714286,
#         1.44642857,  1.93571429,  2.425     ,  2.91428571,  3.40357143,
#         3.89285714,  4.38214286,  4.87142857,  5.36071429,  5.85      ])

# %%
#se le restó uno al mínimo, sumó uno al máximo, y sumó uno al intervalo
#creamos las categorías

categorias = ['0-4.85', '4.85-9.7', '9.7-14.55', '14.55-19.4', '19.4-24.25', '24.25-29.1', '29.1-33.95', '33.95-38.8', '38.8-43.65', '43.65-48.5', '48.5-53.35', '53.35-58.2', '58.2-63.05', '63.05-67.9']

# %%
#Finalmente creamos las categorías en la columna numérica

df['reviews_per_month'] = pd.cut(x=df['reviews_per_month'], bins=intervalos, labels=categorias)
df['reviews_per_month']
# Out:
# 0       33.95-38.8
# 1       24.25-29.1
# 2       53.35-58.2
# 3       33.95-38.8
# 4       14.55-19.4
# 5        9.7-14.55
# 6       14.55-19.4
# 7       14.55-19.4
# 8        9.7-14.55
# 9       19.4-24.25
# 10      24.25-29.1
# 11      43.65-48.5
# 12      14.55-19.4
# 13      14.55-19.4
# 14       9.7-14.55
# 15      33.95-38.8
# 16      24.25-29.1
# 17      19.4-24.25
# 18       9.7-14.55
# 19      19.4-24.25
# 20       9.7-14.55
# 21      14.55-19.4
# 22      14.55-19.4
# 23      19.4-24.25
# 24      14.55-19.4
# 25       9.7-14.55
# 26      14.55-19.4
# 27      14.55-19.4
# 28      29.1-33.95
# 29       9.7-14.55
# 30      33.95-38.8
# 31       9.7-14.55
# 32      29.1-33.95
# 33      48.5-53.35
# 34      14.55-19.4
# 35      19.4-24.25
# 36      14.55-19.4
# 37       9.7-14.55
# 38      14.55-19.4
# 39      19.4-24.25
# 40      19.4-24.25
# 41      14.55-19.4
# 42      14.55-19.4
# 43       9.7-14.55
# 44      14.55-19.4
# 45      19.4-24.25
# 46      14.55-19.4
# ...

# %%
#obtengo un ánalisis univariado de las variables categoricas
tabla_freq20 = df['reviews_per_month'].value_counts(). reset_index()
tabla_freq20
# Out:
#    reviews_per_month  count
# 0          9.7-14.55   2816
# 1         14.55-19.4   1230
# 2         19.4-24.25    923
# 3         24.25-29.1    687
# 4         29.1-33.95    643
# 5         33.95-38.8    460
# 6         38.8-43.65    319
# 7         43.65-48.5    202
# 8         48.5-53.35    152
# 9         53.35-58.2     90
# 10            0-4.85      0
# 11          4.85-9.7      0
# 12        58.2-63.05      0
# 13        63.05-67.9      0

# %%
#obtengo un filtro de los valores más relevantes de la variable categorica seleccionada
filtro20 = tabla_freq20[tabla_freq20['count']>=90]
filtro20
# Out:
#   reviews_per_month  count
# 0         9.7-14.55   2816
# 1        14.55-19.4   1230
# 2        19.4-24.25    923
# 3        24.25-29.1    687
# 4        29.1-33.95    643
# 5        33.95-38.8    460
# 6        38.8-43.65    319
# 7        43.65-48.5    202
# 8        48.5-53.35    152
# 9        53.35-58.2     90

# %%
#ajusto el indice de mi dataframe
filtro_index20 = filtro20.set_index('reviews_per_month')
filtro_index20
# Out:
#                    count
# reviews_per_month
# 9.7-14.55           2816
# 14.55-19.4          1230
# 19.4-24.25           923
# 24.25-29.1           687
# 29.1-33.95           643
# 33.95-38.8           460
# 38.8-43.65           319
# 43.65-48.5           202
# 48.5-53.35           152
# 53.35-58.2            90

# %%
#Realizamos grafico de barras del dataframe filtrado
filtro_index20.plot(kind='bar', width = 0.8, figsize = (10, 4), color = 'red')
plt.title('reviews_per_month')
plt.xlabel('Número de reseñas por mes')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# Por mes, se observan de 10 a 15 reseñas, lo que indica que en Nueva Orlenas existe un algo grado de interacción en un plano mensual.

# %% [markdown]
# A través del análisis univariado podemos obtener una mejor visualización de datos que inicialmente no son categóricos. De esta manera se puede observar por medio de rangos las frecuencias de cualquier variable que nos interese, además de generar comparaciones no solo con la misma base de datos , sino también con otras.
# Esto resulta muy enriquecedor para el análista, pero también para cuando se desea presentar la información de una manera más gráfica y comprensible.
